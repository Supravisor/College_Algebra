# %% [markdown]
# # Function and a table of (x,y) values

# %%
x = 5
y = 4*x + 3 # The function 

print(x,",",y)

print("x \t y") 

for x in range(11):
    y = 4*x + 3  # The function
    print(x, "\t", y)
# Out:
# 5 , 23
# x 	 y
# 0 	 3
# 1 	 7
# 2 	 11
# 3 	 15
# 4 	 19
# 5 	 23
# 6 	 27
# 7 	 31
# 8 	 35
# 9 	 39
# 10 	 43
