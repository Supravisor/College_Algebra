# %% [markdown]
# # Solving Systems

# %% [markdown]
# ## Simplest way to solve a system of equations.
# ## Set each equation equal to zero.

# %%
# !pip install sympy
from sympy import *

x,y = symbols('x y')
