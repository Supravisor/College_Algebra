# %% [markdown]
# # Graphing Systems

# %% [markdown]
# ## Use numpy library instead of a loop

# %%
# !pip install matplotlib
# !pip install numpy
import matplotlib.pyplot as plt
import numpy as np

# %%
xmin = -10
xmax = 10
ymin = -10
ymax = 10
